# %% [markdown]
# # 05 — Graph Neural Network Model
#
# Introduce an optional GCN prototype for graph representation learning.

# %% [markdown]
# ## Why GNNs
#
# A GNN learns from node features and neighbourhood structure jointly.

# %% [markdown]
# ## Semi-supervised setting
#
# Unknown labels can participate in message passing but not supervised loss.

# %% [markdown]
# ## Caution
#
# GNNs can be stronger but are harder to explain and govern.

# %%
# Optional dependency:
# poetry install --with dev,gnn
# from graph_fraud.gnn import SimpleGCN
