# %% [markdown]
# # 03 — Baseline Transaction Feature Model
#
# Build a transaction-feature-only model before adding graph information.

# %% [markdown]
# ## Purpose
#
# A graph model should improve on a clear baseline.

# %% [markdown]
# ## Validation
#
# Use time-based splits, not random splits.

# %% [markdown]
# ## Metrics
#
# Report PR-AUC, ROC-AUC, precision@K and recall@K.
