# %% [markdown]
# # 08 — Limitations, Governance, and Model Risk
#
# Document model-risk and safe-use principles.

# %% [markdown]
# ## Misuse risks
#
# A score can be mistaken for evidence.

# %% [markdown]
# ## False positives
#
# Legitimate users can be affected by graph proximity.

# %% [markdown]
# ## Governance
#
# Require human review, audit logs, validation, and drift monitoring.
