# %% [markdown]
# # 02 — Graph Data Exploration
#
# Explore nodes, edges, labels, class imbalance, and time steps.

# %% [markdown]
# ## Available data
#
# Inspect transaction features, edge list, labels, and time steps.

# %% [markdown]
# ## Graph structure
#
# Compute degree features and component sizes.

# %% [markdown]
# ## Data quality
#
# Check unknown labels, duplicated edges, missing values, and disconnected nodes.

# %%
from graph_fraud.synthetic import make_synthetic_transaction_graph
from graph_fraud.graph import degree_features

nodes, edges = make_synthetic_transaction_graph(n_nodes=500)
display(nodes.head())
display(edges.head())
display(degree_features(nodes, edges).describe())
